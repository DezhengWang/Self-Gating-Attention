# %%
! chmod +x ./scripts_TimeXer/multivariate/ETT/TimeXer_ETTh1.sh
! chmod +x ./scripts_TimeXer/multivariate/ETT/TimeXer_ETTh2.sh
! chmod +x ./scripts_TimeXer/multivariate/ETT/TimeXer_ETTm1.sh
! chmod +x ./scripts_TimeXer/multivariate/ETT/TimeXer_ETTm2.sh
! chmod +x ./scripts_TimeXer/multivariate/ECL/TimeXer.sh
! chmod +x ./scripts_TimeXer/multivariate/Traffic/TimeXer.sh
! chmod +x ./scripts_TimeXer/multivariate/Weather/TimeXer.sh
! chmod +x ./scripts_TimeXer/multivariate/Exchange/TimeXer.sh

# %% [markdown]
# # Re-Train

# %%
! nvidia-smi

# %%
for n_head in [11,12]:
    for pred_len in [96,192,336,720]:
        model_name = "TimeXerWGA"
        d_model = n_head * 64
        d_ff = d_model * 4
        ! ./scripts_TimeXer/multivariate/ETT/TimeXer_ETTh1_ex.sh $model_name 0 96 $pred_len $n_head $d_model $d_ff
        ! ./scripts_TimeXer/multivariate/ETT/TimeXer_ETTh1_ex.sh $model_name 1 96 $pred_len $n_head $d_model $d_ff
        ! ./scripts_TimeXer/multivariate/ETT/TimeXer_ETTh1_ex.sh $model_name 2 96 $pred_len $n_head $d_model $d_ff

# %% [markdown]
# # Main Exp

# %%
model_name = "TimeXerWGA"

# ! ./scripts_TimeXer/multivariate/Weather/TimeXer.sh $model_name 0
# ! ./scripts_TimeXer/multivariate/Weather/TimeXer.sh $model_name 1
# ! ./scripts_TimeXer/multivariate/Weather/TimeXer.sh $model_name 2

# %% [markdown]
# # ETTh

# %%
! ./scripts_TimeXer/multivariate/ETT/TimeXer_ETTh1.sh $model_name 0
! ./scripts_TimeXer/multivariate/ETT/TimeXer_ETTh1.sh $model_name 1
! ./scripts_TimeXer/multivariate/ETT/TimeXer_ETTh1.sh $model_name 2

# ! ./scripts_TimeXer/multivariate/ETT/TimeXer_ETTh2.sh $model_name 0
# ! ./scripts_TimeXer/multivariate/ETT/TimeXer_ETTh2.sh $model_name 1
# ! ./scripts_TimeXer/multivariate/ETT/TimeXer_ETTh2.sh $model_name 2

# %% [markdown]
# # ETTm

# %%
! ./scripts_TimeXer/multivariate/ETT/TimeXer_ETTm1.sh $model_name 0
! ./scripts_TimeXer/multivariate/ETT/TimeXer_ETTm1.sh $model_name 1
! ./scripts_TimeXer/multivariate/ETT/TimeXer_ETTm1.sh $model_name 2

! ./scripts_TimeXer/multivariate/ETT/TimeXer_ETTm2.sh $model_name 0
! ./scripts_TimeXer/multivariate/ETT/TimeXer_ETTm2.sh $model_name 1
! ./scripts_TimeXer/multivariate/ETT/TimeXer_ETTm2.sh $model_name 2

# %% [markdown]
# # Weather

# %%
! ./scripts_TimeXer/multivariate/Weather/TimeXer.sh $model_name 0
! ./scripts_TimeXer/multivariate/Weather/TimeXer.sh $model_name 1
! ./scripts_TimeXer/multivariate/Weather/TimeXer.sh $model_name 2

# %% [markdown]
# # ECL

# %%
! ./scripts_TimeXer/multivariate/ECL/TimeXer.sh $model_name 0
! ./scripts_TimeXer/multivariate/ECL/TimeXer.sh $model_name 1
! ./scripts_TimeXer/multivariate/ECL/TimeXer.sh $model_name 2

# %% [markdown]
# # Traffic

# %%
! ./scripts_TimeXer/multivariate/Traffic/TimeXer.sh $model_name 0
! ./scripts_TimeXer/multivariate/Traffic/TimeXer.sh $model_name 1
! ./scripts_TimeXer/multivariate/Traffic/TimeXer.sh $model_name 2
# Out:
# True
# Args in experiment:
# Basic Config
#   Task Name:          long_term_forecast  Is Training:        1
#   Model ID:           traffic_96_96       Model:              TimeXerWGA
#
# Data Loader
#   Data:               custom              Root Path:          ./dataset/traffic/
#   Data Path:          traffic.csv         Features:           M
#   Target:             OT                  Freq:               h
#   Checkpoints:        ./checkpoints/
#
# Forecasting Task
#   Seq Len:            96                  Label Len:          48
#   Pred Len:           96                  Seasonal Patterns:  Monthly
#   Inverse:            0
#
# Model Parameters
#   Top k:              5                   Num Kernels:        6
#   Enc In:             862                 Dec In:             862
#   C Out:              862                 d model:            512
#   n heads:            8                   e layers:           3
#   d layers:           1                   d FF:               512
# ...

# %% [markdown]
# # Exchange

# %%
for model_name in ["TimeXer", "TimeXerWGA", "TimeXerWAuto", "TimeXerWGeom", "TimeXerWProb", "TimeXerWTOST", ]:
    ! ./scripts_TimeXer/multivariate/Exchange/TimeXer.sh $model_name 0
    ! ./scripts_TimeXer/multivariate/Exchange/TimeXer.sh $model_name 1
    ! ./scripts_TimeXer/multivariate/Exchange/TimeXer.sh $model_name 2

# %%
! ./scripts_TimeXer/multivariate/Exchange/TimeXer.sh $model_name 0
! ./scripts_TimeXer/multivariate/Exchange/TimeXer.sh $model_name 1
! ./scripts_TimeXer/multivariate/Exchange/TimeXer.sh $model_name 2
